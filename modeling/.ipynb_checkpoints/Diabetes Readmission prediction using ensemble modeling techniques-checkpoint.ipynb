# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Check initial metrics for 5 popular modeling techniques using obtained features

# %%
selected_features = ["race", "gender", "age2", "admission_type_id2", "discharge_disposition_id2", "admission_type_id2", "time_in_hospital", "num_lab_procedures", "num_procedures", "num_medications", "number_outpatient_log", "number_emergency_log", "number_inpatient", "number_diagnoses", "max_glu_serum", "A1Cresult", "insulin", "Diabetes Med (Up)", "Diabetes Med (Steady)", "Diabetes Med (Down)", "change", "diabetesMed"]
target = "readmitted2"

# %%
training_df = pd.read_csv("../modeling_data/diabetes_data_v4_p1_70pct.csv", header=0)
training_X = training_df[selected_features]
training_Y = training_df[target]

validation_df = pd.read_csv("../modeling_data/diabetes_data_v4_p2_15pct.csv", header=0)
validation_X = validation_df[selected_features]
validation_Y = validation_df[target]

training_X.head()
# Out:
# G:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (0,1,3,4,5,6,7,11,12,13,14,15,16,17,20,21,22,23,24,25,26,27,28,54,55,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         race  gender     age2  admission_type_id2  discharge_disposition_id2  \
# 0  Caucasian  Female      <30                   1                          1
# 1  Caucasian    Male      >60                   3                          1
# 2  Caucasian  Female      >60                   4                          6
# 3  Caucasian  Female      >60                   2                          1
# 4  Caucasian    Male  30 - 60                   3                          1
#
#    admission_type_id2  time_in_hospital  num_lab_procedures  num_procedures  \
# 0                   1                 2                  33               0
# 1                   3                 2                  33               0
# 2                   4                 5                  47               3
# 3                   2                 5                  32               1
# 4                   3                 3                  32               1
#
#    num_medications     ...       number_inpatient  number_diagnoses  \
# 0                4     ...                      0                 2
# 1               16     ...                      1                 9
# 2               24     ...                      0                 7
# 3               16     ...                      0                 9
# 4                4     ...                      0                 9
#
#    max_glu_serum  A1Cresult insulin Diabetes Med (Up) Diabetes Med (Steady)  \
# 0           None         >8  Steady                 0                     1
# 1           None       None  Steady                 0                     2
# 2           None       None  Steady                 0                     1
# 3           None       Norm  Steady                 0                     1
# 4           None         >8      No                 0                     0
#
#    Diabetes Med (Down)  change  diabetesMed
# 0                    0      No          Yes
# 1                    0      Ch          Yes
# 2                    0      No          Yes
# 3                    0      No          Yes
# 4                    0      No           No
#
# [5 rows x 22 columns]

# %%
training_Y.head()
